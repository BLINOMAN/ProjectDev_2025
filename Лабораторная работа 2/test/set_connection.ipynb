# %%
from sqlalchemy import create_engine

def get_engine(connect_url):
    engine = create_engine(
        connect_url,
        echo=True  # Логирование SQL-запросов
    )
    return engine

# %%
engine = get_engine(connect_url='postgresql+psycopg2://postgres:postgres@localhost/test_db')

# %%
engine
# Out:
# Engine(postgresql+psycopg2://postgres:***@localhost/test_db)

# %%
from orm.main import User
from sqlalchemy.orm import sessionmaker 

session_factory = sessionmaker(engine)

with session_factory() as session:
    users = [User(username="Boris Muratshin", email='muratshinboris@gmail.com'), 
             User(username="Alexey Kuzmin", email='lehakuz@gmail.com'),
             User(username="Alina Trinz", email='coolalina@gmail.com'),
             User(username="Ekaterina Nixon", email='nixonkat@gmail.com'),
             User(username="Donald Trump", email='realdonald@gmail.com')]
    
    for i in users:
        session.add(i)
        session.commit()
# Out:
# 2025-10-22 00:07:30,085 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-10-22 00:07:30,086 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:07:30,088 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-10-22 00:07:30,089 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:07:30,091 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-10-22 00:07:30,091 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:07:30,094 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:30,095 INFO sqlalchemy.engine.Engine INSERT INTO users (id, username, email, created_at, updated_at, description) VALUES (%(id)s::UUID, %(username)s, %(email)s, %(created_at)s, %(updated_at)s, %(description)s)
# 2025-10-22 00:07:30,096 INFO sqlalchemy.engine.Engine [generated in 0.00078s] {'id': UUID('0f380d46-d24d-48d0-b75c-b564d9b01aac'), 'username': 'Boris Muratshin', 'email': 'muratshinboris@gmail.com', 'created_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 95103), 'updated_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 95103), 'description': 'No description'}
# 2025-10-22 00:07:30,099 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:07:30,102 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:30,103 INFO sqlalchemy.engine.Engine INSERT INTO users (id, username, email, created_at, updated_at, description) VALUES (%(id)s::UUID, %(username)s, %(email)s, %(created_at)s, %(updated_at)s, %(description)s)
# 2025-10-22 00:07:30,104 INFO sqlalchemy.engine.Engine [cached since 0.00874s ago] {'id': UUID('f2048d04-0d58-4fcf-925c-a5912ed77253'), 'username': 'Alexey Kuzmin', 'email': 'lehakuz@gmail.com', 'created_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 103634), 'updated_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 103634), 'description': 'No description'}
# 2025-10-22 00:07:30,105 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:07:30,108 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:30,109 INFO sqlalchemy.engine.Engine INSERT INTO users (id, username, email, created_at, updated_at, description) VALUES (%(id)s::UUID, %(username)s, %(email)s, %(created_at)s, %(updated_at)s, %(description)s)
# 2025-10-22 00:07:30,110 INFO sqlalchemy.engine.Engine [cached since 0.01516s ago] {'id': UUID('f6fc9350-c1c9-46f1-aaa1-f40a9691bc79'), 'username': 'Alina Trinz', 'email': 'coolalina@gmail.com', 'created_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 109652), 'updated_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 109652), 'description': 'No description'}
# 2025-10-22 00:07:30,112 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:07:30,116 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:30,116 INFO sqlalchemy.engine.Engine INSERT INTO users (id, username, email, created_at, updated_at, description) VALUES (%(id)s::UUID, %(username)s, %(email)s, %(created_at)s, %(updated_at)s, %(description)s)
# 2025-10-22 00:07:30,117 INFO sqlalchemy.engine.Engine [cached since 0.02229s ago] {'id': UUID('ce2b4af5-e5f9-4f2d-8beb-75922c72007b'), 'username': 'Ekaterina Nixon', 'email': 'nixonkat@gmail.com', 'created_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 116753), 'updated_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 116753), 'description': 'No description'}
# 2025-10-22 00:07:30,119 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:07:30,122 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:30,123 INFO sqlalchemy.engine.Engine INSERT INTO users (id, username, email, created_at, updated_at, description) VALUES (%(id)s::UUID, %(username)s, %(email)s, %(created_at)s, %(updated_at)s, %(description)s)
# 2025-10-22 00:07:30,123 INFO sqlalchemy.engine.Engine [cached since 0.02847s ago] {'id': UUID('54dc6c82-2776-4b24-8d85-417f51ef9a98'), 'username': 'Donald Trump', 'email': 'realdonald@gmail.com', 'created_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 123839), 'updated_at': datetime.datetime(2025, 10, 22, 0, 7, 30, 123839), 'description': 'No description'}
# 2025-10-22 00:07:30,125 INFO sqlalchemy.engine.Engine COMMIT

# %%
from orm.main import User
from sqlalchemy.orm import sessionmaker 
from sqlalchemy import select
from sqlalchemy.orm import selectinload

session_factory = sessionmaker(engine)

with session_factory() as session:
    slct = select(User).options(selectinload(User.addresses)).select()
    result = session.execute(slct)
    print(result.all())
# Out:
# 2025-10-22 00:07:37,328 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:07:37,329 INFO sqlalchemy.engine.Engine SELECT anon_1.id, anon_1.username, anon_1.email, anon_1.created_at, anon_1.updated_at, anon_1.description
# FROM (SELECT users.id AS id, users.username AS username, users.email AS email, users.created_at AS created_at, users.updated_at AS updated_at, users.description AS description
# FROM users) AS anon_1
# 2025-10-22 00:07:37,331 INFO sqlalchemy.engine.Engine [generated in 0.00075s] {}
# [(UUID('0f380d46-d24d-48d0-b75c-b564d9b01aac'), 'Boris Muratshin', 'muratshinboris@gmail.com', datetime.datetime(2025, 10, 22, 0, 7, 30, 95103), datetime.datetime(2025, 10, 22, 0, 7, 30, 95103), 'No description'), (UUID('f2048d04-0d58-4fcf-925c-a5912ed77253'), 'Alexey Kuzmin', 'lehakuz@gmail.com', datetime.datetime(2025, 10, 22, 0, 7, 30, 103634), datetime.datetime(2025, 10, 22, 0, 7, 30, 103634), 'No description'), (UUID('f6fc9350-c1c9-46f1-aaa1-f40a9691bc79'), 'Alina Trinz', 'coolalina@gmail.com', datetime.datetime(2025, 10, 22, 0, 7, 30, 109652), datetime.datetime(2025, 10, 22, 0, 7, 30, 109652), 'No description'), (UUID('ce2b4af5-e5f9-4f2d-8beb-75922c72007b'), 'Ekaterina Nixon', 'nixonkat@gmail.com', datetime.datetime(2025, 10, 22, 0, 7, 30, 116753), datetime.datetime(2025, 10, 22, 0, 7, 30, 116753), 'No description'), (UUID('54dc6c82-2776-4b24-8d85-417f51ef9a98'), 'Donald Trump', 'realdonald@gmail.com', datetime.datetime(2025, 10, 22, 0, 7, 30, 123839), datetime.datetime(2025, 10, 22, 0, 7, 30, 123839), 'No description')]
# 2025-10-22 00:07:37,334 INFO sqlalchemy.engine.Engine ROLLBACK
# C:\Users\Boris\AppData\Local\Temp\ipykernel_26984\2163880900.py:9: SADeprecationWarning: The SelectBase.select() method is deprecated and will be removed in a future release; this method implicitly creates a subquery that should be explicit.  Please call SelectBase.subquery() first in order to create a subquery, which then can be selected. (deprecated since: 1.4)
#   slct = select(User).options(selectinload(User.addresses)).select()

# %%
from orm.main import User, Address
from sqlalchemy.orm import sessionmaker 

session_factory = sessionmaker(engine)

with session_factory() as session:
    addresses = [Address(user_id="0f380d46-d24d-48d0-b75c-b564d9b01aac", street="Michurina 43a", city="Yekaterinburg", country="Russia"),
                 Address(user_id="f2048d04-0d58-4fcf-925c-a5912ed77253", street="Lenina 81", city="Yekaterinburg", country="Russia"),
                 Address(user_id="f6fc9350-c1c9-46f1-aaa1-f40a9691bc79", street="Taticheva 50", city="Yekaterinburg", country="Russia"),
                 Address(user_id="ce2b4af5-e5f9-4f2d-8beb-75922c72007b", street="Tokarey 1", city="Yekaterinburg", country="Russia"),
                 Address(user_id="54dc6c82-2776-4b24-8d85-417f51ef9a98", street="Gorykogo 4b", city="Yekaterinburg", country="Russia")]
    
    for i in addresses:
        session.add(i)
        session.commit()
# Out:
# 2025-10-22 00:15:13,706 INFO sqlalchemy.engine.Engine select pg_catalog.version()
# 2025-10-22 00:15:13,706 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:15:13,712 INFO sqlalchemy.engine.Engine select current_schema()
# 2025-10-22 00:15:13,712 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:15:13,714 INFO sqlalchemy.engine.Engine show standard_conforming_strings
# 2025-10-22 00:15:13,715 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2025-10-22 00:15:13,716 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:15:13,718 INFO sqlalchemy.engine.Engine INSERT INTO addresses (id, user_id, street, city, state, zip_code, country, is_primary, created_at, updated_at) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(street)s, %(city)s, %(state)s, %(zip_code)s, %(country)s, %(is_primary)s, %(created_at)s, %(updated_at)s)
# 2025-10-22 00:15:13,718 INFO sqlalchemy.engine.Engine [generated in 0.00062s] {'id': UUID('3b734f55-ff80-4f10-b77d-b4c6cc0e9498'), 'user_id': '0f380d46-d24d-48d0-b75c-b564d9b01aac', 'street': 'Michurina 43a', 'city': 'Yekaterinburg', 'state': None, 'zip_code': None, 'country': 'Russia', 'is_primary': False, 'created_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 718702), 'updated_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 718702)}
# 2025-10-22 00:15:13,722 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:15:13,725 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:15:13,726 INFO sqlalchemy.engine.Engine INSERT INTO addresses (id, user_id, street, city, state, zip_code, country, is_primary, created_at, updated_at) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(street)s, %(city)s, %(state)s, %(zip_code)s, %(country)s, %(is_primary)s, %(created_at)s, %(updated_at)s)
# 2025-10-22 00:15:13,726 INFO sqlalchemy.engine.Engine [cached since 0.008641s ago] {'id': UUID('cb639687-82c8-4e6d-a948-4e527bb7cd34'), 'user_id': 'f2048d04-0d58-4fcf-925c-a5912ed77253', 'street': 'Lenina 81', 'city': 'Yekaterinburg', 'state': None, 'zip_code': None, 'country': 'Russia', 'is_primary': False, 'created_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 726557), 'updated_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 726557)}
# 2025-10-22 00:15:13,729 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:15:13,732 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:15:13,733 INFO sqlalchemy.engine.Engine INSERT INTO addresses (id, user_id, street, city, state, zip_code, country, is_primary, created_at, updated_at) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(street)s, %(city)s, %(state)s, %(zip_code)s, %(country)s, %(is_primary)s, %(created_at)s, %(updated_at)s)
# 2025-10-22 00:15:13,734 INFO sqlalchemy.engine.Engine [cached since 0.01593s ago] {'id': UUID('2d6bb3e8-117f-47ec-bb81-c1914a963be4'), 'user_id': 'f6fc9350-c1c9-46f1-aaa1-f40a9691bc79', 'street': 'Taticheva 50', 'city': 'Yekaterinburg', 'state': None, 'zip_code': None, 'country': 'Russia', 'is_primary': False, 'created_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 733803), 'updated_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 733803)}
# 2025-10-22 00:15:13,736 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:15:13,740 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:15:13,740 INFO sqlalchemy.engine.Engine INSERT INTO addresses (id, user_id, street, city, state, zip_code, country, is_primary, created_at, updated_at) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(street)s, %(city)s, %(state)s, %(zip_code)s, %(country)s, %(is_primary)s, %(created_at)s, %(updated_at)s)
# 2025-10-22 00:15:13,743 INFO sqlalchemy.engine.Engine [cached since 0.02448s ago] {'id': UUID('04243e91-d4ba-446c-9808-162d67b5817f'), 'user_id': 'ce2b4af5-e5f9-4f2d-8beb-75922c72007b', 'street': 'Tokarey 1', 'city': 'Yekaterinburg', 'state': None, 'zip_code': None, 'country': 'Russia', 'is_primary': False, 'created_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 740084), 'updated_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 740084)}
# 2025-10-22 00:15:13,745 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:15:13,746 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:15:13,749 INFO sqlalchemy.engine.Engine INSERT INTO addresses (id, user_id, street, city, state, zip_code, country, is_primary, created_at, updated_at) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(street)s, %(city)s, %(state)s, %(zip_code)s, %(country)s, %(is_primary)s, %(created_at)s, %(updated_at)s)
# 2025-10-22 00:15:13,750 INFO sqlalchemy.engine.Engine [cached since 0.03196s ago] {'id': UUID('a1abf806-e36b-49d8-88ac-b447152a7823'), 'user_id': '54dc6c82-2776-4b24-8d85-417f51ef9a98', 'street': 'Gorykogo 4b', 'city': 'Yekaterinburg', 'state': None, 'zip_code': None, 'country': 'Russia', 'is_primary': False, 'created_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 749972), 'updated_at': datetime.datetime(2025, 10, 22, 0, 15, 13, 749972)}
# 2025-10-22 00:15:13,753 INFO sqlalchemy.engine.Engine COMMIT

# %%
from orm.main import Product
from sqlalchemy.orm import sessionmaker 

session_factory = sessionmaker(engine)

with session_factory() as session:
    products = [Product(name='Banana', price=150),
                Product(name='Apple', price=100),
                Product(name='Milk', price=89),
                Product(name='Bread', price=50),
                Product(name='Sauce', price=250)]
    
    for i in products:
        session.add(i)
        session.commit()
# Out:
# 2025-10-22 00:18:07,607 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:18:07,608 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, description, price) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(price)s)
# 2025-10-22 00:18:07,609 INFO sqlalchemy.engine.Engine [generated in 0.00060s] {'id': UUID('4e97c190-8b81-4224-94fc-ed0305caae0f'), 'name': 'Banana', 'description': 'No description', 'price': 150}
# 2025-10-22 00:18:07,611 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:18:07,615 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:18:07,616 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, description, price) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(price)s)
# 2025-10-22 00:18:07,617 INFO sqlalchemy.engine.Engine [cached since 0.008741s ago] {'id': UUID('8d77b056-93d4-4557-8dd8-dbd6a2ac54d3'), 'name': 'Apple', 'description': 'No description', 'price': 100}
# 2025-10-22 00:18:07,620 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:18:07,623 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:18:07,624 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, description, price) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(price)s)
# 2025-10-22 00:18:07,624 INFO sqlalchemy.engine.Engine [cached since 0.016s ago] {'id': UUID('1c0f199c-e643-40c7-b938-0ba913e7ccf8'), 'name': 'Milk', 'description': 'No description', 'price': 89}
# 2025-10-22 00:18:07,626 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:18:07,629 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:18:07,630 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, description, price) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(price)s)
# 2025-10-22 00:18:07,630 INFO sqlalchemy.engine.Engine [cached since 0.02224s ago] {'id': UUID('ddd0c696-8851-4ac4-af4d-1b69b74bb01e'), 'name': 'Bread', 'description': 'No description', 'price': 50}
# 2025-10-22 00:18:07,634 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:18:07,637 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:18:07,638 INFO sqlalchemy.engine.Engine INSERT INTO products (id, name, description, price) VALUES (%(id)s::UUID, %(name)s, %(description)s, %(price)s)
# 2025-10-22 00:18:07,639 INFO sqlalchemy.engine.Engine [cached since 0.03032s ago] {'id': UUID('8a2e0bc4-a792-40b4-a13d-e9dee0fd5e07'), 'name': 'Sauce', 'description': 'No description', 'price': 250}
# 2025-10-22 00:18:07,641 INFO sqlalchemy.engine.Engine COMMIT

# %%
from orm.main import Order
from sqlalchemy.orm import sessionmaker 

session_factory = sessionmaker(engine)

with session_factory() as session:
    orders = [Order(user_id="0f380d46-d24d-48d0-b75c-b564d9b01aac", product_id="4e97c190-8b81-4224-94fc-ed0305caae0f",   address_id="3b734f55-ff80-4f10-b77d-b4c6cc0e9498"),
                Order(user_id="f2048d04-0d58-4fcf-925c-a5912ed77253", product_id="8d77b056-93d4-4557-8dd8-dbd6a2ac54d3", address_id="cb639687-82c8-4e6d-a948-4e527bb7cd34"),
                Order(user_id="f6fc9350-c1c9-46f1-aaa1-f40a9691bc79", product_id="1c0f199c-e643-40c7-b938-0ba913e7ccf8", address_id="2d6bb3e8-117f-47ec-bb81-c1914a963be4"),
                Order(user_id="ce2b4af5-e5f9-4f2d-8beb-75922c72007b", product_id="ddd0c696-8851-4ac4-af4d-1b69b74bb01e", address_id="04243e91-d4ba-446c-9808-162d67b5817f"),
                Order(user_id="54dc6c82-2776-4b24-8d85-417f51ef9a98", product_id="8a2e0bc4-a792-40b4-a13d-e9dee0fd5e07", address_id="a1abf806-e36b-49d8-88ac-b447152a7823")]
    
    for i in orders:
        session.add(i)
        session.commit()
# Out:
# 2025-10-22 00:24:48,911 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:24:48,913 INFO sqlalchemy.engine.Engine INSERT INTO orders (id, user_id, address_id, product_id) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(address_id)s::UUID, %(product_id)s::UUID)
# 2025-10-22 00:24:48,914 INFO sqlalchemy.engine.Engine [generated in 0.00121s] {'id': UUID('143ba21a-1717-4952-b3d9-e9aac88c28f1'), 'user_id': '0f380d46-d24d-48d0-b75c-b564d9b01aac', 'address_id': '3b734f55-ff80-4f10-b77d-b4c6cc0e9498', 'product_id': '4e97c190-8b81-4224-94fc-ed0305caae0f'}
# 2025-10-22 00:24:48,917 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:24:48,921 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:24:48,922 INFO sqlalchemy.engine.Engine INSERT INTO orders (id, user_id, address_id, product_id) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(address_id)s::UUID, %(product_id)s::UUID)
# 2025-10-22 00:24:48,923 INFO sqlalchemy.engine.Engine [cached since 0.01005s ago] {'id': UUID('356243ba-b1e0-4f19-8a0e-bf84292891c4'), 'user_id': 'f2048d04-0d58-4fcf-925c-a5912ed77253', 'address_id': 'cb639687-82c8-4e6d-a948-4e527bb7cd34', 'product_id': '8d77b056-93d4-4557-8dd8-dbd6a2ac54d3'}
# 2025-10-22 00:24:48,925 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:24:48,928 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:24:48,929 INFO sqlalchemy.engine.Engine INSERT INTO orders (id, user_id, address_id, product_id) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(address_id)s::UUID, %(product_id)s::UUID)
# 2025-10-22 00:24:48,930 INFO sqlalchemy.engine.Engine [cached since 0.01736s ago] {'id': UUID('c824a35d-02f4-45f7-bab2-55187d641f97'), 'user_id': 'f6fc9350-c1c9-46f1-aaa1-f40a9691bc79', 'address_id': '2d6bb3e8-117f-47ec-bb81-c1914a963be4', 'product_id': '1c0f199c-e643-40c7-b938-0ba913e7ccf8'}
# 2025-10-22 00:24:48,933 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:24:48,937 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:24:48,938 INFO sqlalchemy.engine.Engine INSERT INTO orders (id, user_id, address_id, product_id) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(address_id)s::UUID, %(product_id)s::UUID)
# 2025-10-22 00:24:48,939 INFO sqlalchemy.engine.Engine [cached since 0.0266s ago] {'id': UUID('9ea49915-4000-4208-b78b-816b35a978b1'), 'user_id': 'ce2b4af5-e5f9-4f2d-8beb-75922c72007b', 'address_id': '04243e91-d4ba-446c-9808-162d67b5817f', 'product_id': 'ddd0c696-8851-4ac4-af4d-1b69b74bb01e'}
# 2025-10-22 00:24:48,941 INFO sqlalchemy.engine.Engine COMMIT
# 2025-10-22 00:24:48,948 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-10-22 00:24:48,948 INFO sqlalchemy.engine.Engine INSERT INTO orders (id, user_id, address_id, product_id) VALUES (%(id)s::UUID, %(user_id)s::UUID, %(address_id)s::UUID, %(product_id)s::UUID)
# 2025-10-22 00:24:48,950 INFO sqlalchemy.engine.Engine [cached since 0.03779s ago] {'id': UUID('1131c73e-1436-4373-be63-45b084af9171'), 'user_id': '54dc6c82-2776-4b24-8d85-417f51ef9a98', 'address_id': 'a1abf806-e36b-49d8-88ac-b447152a7823', 'product_id': '8a2e0bc4-a792-40b4-a13d-e9dee0fd5e07'}
# 2025-10-22 00:24:48,953 INFO sqlalchemy.engine.Engine COMMIT

# %%
# Out:
# C:\Users\Boris\AppData\Local\Temp\ipykernel_35516\3448662538.py:4: SADeprecationWarning: The SelectBase.select() method is deprecated and will be removed in a future release; this method implicitly creates a subquery that should be explicit.  Please call SelectBase.subquery() first in order to create a subquery, which then can be selected. (deprecated since: 1.4)
#   select(User).options(selectinload(User.addresses)).select()
